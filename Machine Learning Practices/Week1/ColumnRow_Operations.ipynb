# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(9,4),index=list("abcdefghi"),columns=list("ABCD"))
df
# Out:
#           A         B         C         D
# a  0.105237  0.204313  0.928050  0.414034
# b  0.808914  0.476929  0.836859  0.436202
# c  0.176967  0.754226  0.232854  0.462156
# d  0.376259  0.654727  0.979483  0.078533
# e  0.999414  0.931427  0.690028  0.934723
# f  0.537415  0.043213  0.935266  0.274600
# g  0.750017  0.302175  0.436093  0.830261
# h  0.108089  0.517812  0.852633  0.290776
# i  0.437074  0.294398  0.078466  0.164771

# %% [markdown]
# **Adding a column in the dataframe**

# %%
df["E"] = df["A"] * 100

# %%
df
# Out:
#           A         B         C         D          E
# a  0.105237  0.204313  0.928050  0.414034  10.523665
# b  0.808914  0.476929  0.836859  0.436202  80.891364
# c  0.176967  0.754226  0.232854  0.462156  17.696683
# d  0.376259  0.654727  0.979483  0.078533  37.625913
# e  0.999414  0.931427  0.690028  0.934723  99.941440
# f  0.537415  0.043213  0.935266  0.274600  53.741504
# g  0.750017  0.302175  0.436093  0.830261  75.001748
# h  0.108089  0.517812  0.852633  0.290776  10.808892
# i  0.437074  0.294398  0.078466  0.164771  43.707406

# %%
df['F'] = df['A'] + df['C']
df
# Out:
#           A         B         C         D          E         F
# a  0.105237  0.204313  0.928050  0.414034  10.523665  1.033286
# b  0.808914  0.476929  0.836859  0.436202  80.891364  1.645772
# c  0.176967  0.754226  0.232854  0.462156  17.696683  0.409821
# d  0.376259  0.654727  0.979483  0.078533  37.625913  1.355742
# e  0.999414  0.931427  0.690028  0.934723  99.941440  1.689442
# f  0.537415  0.043213  0.935266  0.274600  53.741504  1.472681
# g  0.750017  0.302175  0.436093  0.830261  75.001748  1.186111
# h  0.108089  0.517812  0.852633  0.290776  10.808892  0.960722
# i  0.437074  0.294398  0.078466  0.164771  43.707406  0.515540

# %%
criteria = df['A'] < 0.2

# %%
criteria
# Out:
# a     True
# b    False
# c     True
# d    False
# e    False
# f    False
# g    False
# h     True
# i    False
# Name: A, dtype: bool

# %%
df.loc[criteria, 'A'] = 0
df
# Out:
#           A         B         C         D          E         F
# a  0.000000  0.204313  0.928050  0.414034  10.523665  1.033286
# b  0.808914  0.476929  0.836859  0.436202  80.891364  1.645772
# c  0.000000  0.754226  0.232854  0.462156  17.696683  0.409821
# d  0.376259  0.654727  0.979483  0.078533  37.625913  1.355742
# e  0.999414  0.931427  0.690028  0.934723  99.941440  1.689442
# f  0.537415  0.043213  0.935266  0.274600  53.741504  1.472681
# g  0.750017  0.302175  0.436093  0.830261  75.001748  1.186111
# h  0.000000  0.517812  0.852633  0.290776  10.808892  0.960722
# i  0.437074  0.294398  0.078466  0.164771  43.707406  0.515540

# %%
df.loc[df['A'] == 0, 'A'] = 1
df
# Out:
#           A         B         C         D          E         F
# a  1.000000  0.204313  0.928050  0.414034  10.523665  1.033286
# b  0.808914  0.476929  0.836859  0.436202  80.891364  1.645772
# c  1.000000  0.754226  0.232854  0.462156  17.696683  0.409821
# d  0.376259  0.654727  0.979483  0.078533  37.625913  1.355742
# e  0.999414  0.931427  0.690028  0.934723  99.941440  1.689442
# f  0.537415  0.043213  0.935266  0.274600  53.741504  1.472681
# g  0.750017  0.302175  0.436093  0.830261  75.001748  1.186111
# h  1.000000  0.517812  0.852633  0.290776  10.808892  0.960722
# i  0.437074  0.294398  0.078466  0.164771  43.707406  0.515540

# %%
df.loc[df['A'] < 1, ['A','B']] = [100,300]
df
# Out:
#        A           B         C         D          E         F
# a    1.0    0.204313  0.928050  0.414034  10.523665  1.033286
# b  100.0  300.000000  0.836859  0.436202  80.891364  1.645772
# c    1.0    0.754226  0.232854  0.462156  17.696683  0.409821
# d  100.0  300.000000  0.979483  0.078533  37.625913  1.355742
# e  100.0  300.000000  0.690028  0.934723  99.941440  1.689442
# f  100.0  300.000000  0.935266  0.274600  53.741504  1.472681
# g  100.0  300.000000  0.436093  0.830261  75.001748  1.186111
# h    1.0    0.517812  0.852633  0.290776  10.808892  0.960722
# i  100.0  300.000000  0.078466  0.164771  43.707406  0.515540

# %%
df.loc[df['A'] == 100, 'B'] = df['D'] *2
df
# Out:
#        A         B         C         D          E         F
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540

# %%
cities = ['Mumbai','Delhi','Chennai','Kolkata','Bengaluru','Hyderabad','Pune','Ahmedabad','Indore']

# %%
df['city'] = cities

# %%
df
# Out:
#        A         B         C         D          E         F       city
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bengaluru
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore

# %%
cities_new = ['Mumbai','Delhi','Chennai','Kolkata','Bengaluru','Hyderabad','Pune','Ahmedabad',np.NaN]

# %%
df['city_new'] = cities_new
df
# Out:
#        A         B         C         D          E         F       city  \
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bengaluru
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore
#
#     city_new
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bengaluru
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i        NaN

# %%
df_copy = df.copy()
df_copy
# Out:
#        A         B         C         D          E         F       city  \
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bengaluru
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore
#
#     city_new
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bengaluru
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i        NaN

# %%
criteria1 = df_copy['city'].isin(['Pune','Regina','Hyderabad'])

# %%
criteria1
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f     True
# g     True
# h    False
# i    False
# Name: city, dtype: bool

# %%
df_copy
# Out:
#        A         B         C         D          E         F       city  \
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bengaluru
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore
#
#     city_new
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bengaluru
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i        NaN

# %%
df_copy.loc[df_copy.city == 'Bengaluru',['city','city_new']] = 'Bangalore'
df_copy
# Out:
#        A         B         C         D          E         F       city  \
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bangalore
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore
#
#     city_new
# a     Mumbai
# b      Delhi
# c    Chennai
# d    Kolkata
# e  Bangalore
# f  Hyderabad
# g       Pune
# h  Ahmedabad
# i        NaN

# %%
# ?df_copy.drop

# %%
df_copy = df_copy.drop('city_new',axis=1)
df_copy
# Out:
#        A         B         C         D          E         F       city
# a    1.0  0.204313  0.928050  0.414034  10.523665  1.033286     Mumbai
# b  100.0  0.872404  0.836859  0.436202  80.891364  1.645772      Delhi
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bangalore
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore

# %%
df_copy = df_copy.drop(['a','b'])
df_copy
# Out:
#        A         B         C         D          E         F       city
# c    1.0  0.754226  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.157065  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  1.869445  0.690028  0.934723  99.941440  1.689442  Bangalore
# f  100.0  0.549200  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  1.660521  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.517812  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.329542  0.078466  0.164771  43.707406  0.515540     Indore

# %%
df_copy = df_copy.drop(columns=['B'])
df_copy
# Out:
#        A         C         D          E         F       city
# c    1.0  0.232854  0.462156  17.696683  0.409821    Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742    Kolkata
# e  100.0  0.690028  0.934723  99.941440  1.689442  Bangalore
# f  100.0  0.935266  0.274600  53.741504  1.472681  Hyderabad
# g  100.0  0.436093  0.830261  75.001748  1.186111       Pune
# h    1.0  0.852633  0.290776  10.808892  0.960722  Ahmedabad
# i  100.0  0.078466  0.164771  43.707406  0.515540     Indore

# %%
df_copy.loc[:,'city'] = 'Chennai'

# %%
df_copy
# Out:
#        A         C         D          E         F     city
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# e  100.0  0.690028  0.934723  99.941440  1.689442  Chennai
# f  100.0  0.935266  0.274600  53.741504  1.472681  Chennai
# g  100.0  0.436093  0.830261  75.001748  1.186111  Chennai
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# i  100.0  0.078466  0.164771  43.707406  0.515540  Chennai

# %%
df_copy.loc['j'] =[1,2,3,4,5,'Mumbai']

# %%
df_copy
# Out:
#        A         C         D          E         F     city
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# e  100.0  0.690028  0.934723  99.941440  1.689442  Chennai
# f  100.0  0.935266  0.274600  53.741504  1.472681  Chennai
# g  100.0  0.436093  0.830261  75.001748  1.186111  Chennai
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# i  100.0  0.078466  0.164771  43.707406  0.515540  Chennai
# j    1.0  2.000000  3.000000   4.000000  5.000000   Mumbai

# %% [markdown]
# **Sample and random_state**

# %%
# ?df_copy.sample

# %%
df_copy.sample(4)
# Out:
#        A         C         D          E         F     city
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# f  100.0  0.935266  0.274600  53.741504  1.472681  Chennai
# e  100.0  0.690028  0.934723  99.941440  1.689442  Chennai
# g  100.0  0.436093  0.830261  75.001748  1.186111  Chennai

# %%
df_copy.sample(3)
# Out:
#        A         C         D          E         F     city
# j    1.0  2.000000  3.000000   4.000000  5.000000   Mumbai
# g  100.0  0.436093  0.830261  75.001748  1.186111  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
df_copy.sample(3, random_state=42)
# Out:
#        A         C         D          E         F     city
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
df_copy.sample(3, random_state=42)
# Out:
#        A         C         D          E         F     city
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
df_copy.sample(3, replace=True)
# Out:
#        A         C         D          E         F     city
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# f  100.0  0.935266  0.274600  53.741504  1.472681  Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai

# %%
df_copy.sample(3, replace=True)
# Out:
#        A         C         D          E         F     city
# f  100.0  0.935266  0.274600  53.741504  1.472681  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
df_copy.sample(3, replace=True)
# Out:
#        A         C         D          E         F     city
# g  100.0  0.436093  0.830261  75.001748  1.186111  Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai

# %%
df_copy.sample(3, random_state=42)
# Out:
#        A         C         D          E         F     city
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# h    1.0  0.852633  0.290776  10.808892  0.960722  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
df_copy.sample(3, random_state=40)
# Out:
#        A         C         D          E         F     city
# j    1.0  2.000000  3.000000   4.000000  5.000000   Mumbai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# e  100.0  0.690028  0.934723  99.941440  1.689442  Chennai

# %%
df_copy.sample(3, random_state=40)
# Out:
#        A         C         D          E         F     city
# j    1.0  2.000000  3.000000   4.000000  5.000000   Mumbai
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# e  100.0  0.690028  0.934723  99.941440  1.689442  Chennai

# %%
df_copy.sample(3, random_state=90)
# Out:
#        A         C         D          E         F     city
# d  100.0  0.979483  0.078533  37.625913  1.355742  Chennai
# i  100.0  0.078466  0.164771  43.707406  0.515540  Chennai
# c    1.0  0.232854  0.462156  17.696683  0.409821  Chennai

# %%
cities = ['Regina','Saskatoon','Toronto','Vancouver','Montreal','Ottawa','Winnipeg']
city_df = pd.DataFrame(cities)

# %%
city_df.columns = ['City_Name']

# %%
city_df
# Out:
#    City_Name
# 0     Regina
# 1  Saskatoon
# 2    Toronto
# 3  Vancouver
# 4   Montreal
# 5     Ottawa
# 6   Winnipeg

# %%
condition1 = city_df.City_Name == 'Regina'

# %%
condition1
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: City_Name, dtype: bool

# %%
city_df[condition1]
# Out:
#   City_Name
# 0    Regina

# %%
condition2 = city_df.City_Name == 'Toronto'
print(condition2)
print(type(condition2))
print(city_df[condition2])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# Name: City_Name, dtype: bool
# <class 'pandas.core.series.Series'>
#   City_Name
# 2   Toronto
